# %%
import os
import wandb
import torch
from pathlib import Path

def download_and_modify_weights(run_id, output_folder):
    # Initialize wandb API
    api = wandb.Api()

    # Get the run
    try:
        run = api.run(run_id)
    except wandb.errors.CommError:
        print(f"Error: Unable to find run with id {run_id}")
        return

    # Find the file ending with 'best_success_rate.pt'
    best_file = None
    for file in run.files():
        if file.name.endswith('best_success_rate.pt'):
            best_file = file
            break

    if not best_file:
        print(f"Error: No file ending with 'best_success_rate.pt' found for run {run_id}")
        return

    # Download the file
    best_file.download(replace=True)

    # Load the weights
    weights = torch.load(best_file.name)

    # Add the run config to the weights
    weights['config'] = run.config

    # Create the output folder if it doesn't exist
    output_folder = Path(output_folder)
    output_folder.mkdir(parents=True, exist_ok=True)

    # Save the modified weights with the new simplified filename
    output_path = output_folder / "actor_chkpt.pt"
    
    torch.save(weights, str(output_path))

    print(f"Modified weights for run {run_id} saved to {output_path}")

def process_runs(run_dict):
    checkpoint_path = Path(os.environ.get('CHECKPOINT_PATH', ''))
    
    for output_folder, run_id in run_dict.items():
        full_output_path = checkpoint_path / output_folder
        print(f"Processing run {run_id} to output folder {full_output_path}")
        download_and_modify_weights(run_id, full_output_path)

# %%
os.environ["CHECKPOINT_PATH"] = "/data/scratch/ankile/rr-best-checkpoints"

# %%
# Example usage
runs_to_process = {
    "bc/one_leg/low": "ol-state-dr-1/e3d4a367",
    "bc/one_leg/med": "ol-state-dr-med-1/9zjnzg4r",
    "bc/round_table/low": "rt-state-dr-low-1/z3efusm6",
    "bc/round_table/med": "rt-state-dr-med-1/n5g6x9jg",
    "bc/lamp/low": "lp-state-dr-low-1/b5dcl1tt",
    "bc/lamp/med": "lp-state-dr-med-1/fziwvs8k",
    "bc/mug_rack/low": "mr-state-dr-low-1/uet1h1ex",
    "bc/factory_peg_hole/low": "fph-state-dr-low-1/4vwizwue",
    "rppo/one_leg/low": "ol-rppo-dr-low-1/jamz5ley",
    "rppo/one_leg/med": "ol-rppo-dr-med-1/oipdyimz",
    "rppo/round_table/low": "rt-rppo-dr-low-1/np48i8wp",
    "rppo/round_table/med": "rt-rppo-dr-med-1/k737s8lj",
    "rppo/lamp/low": "lp-rppo-dr-low-1/hd2i5gje",
    "rppo/lamp/med": "lp-rppo-dr-med-1/ev23t35c",
    "rppo/mug_rack/low": "mr-rppo-dr-low-1/dvw6zk8e",
    "rppo/factory_peg_hole/low": "fph-rppo-dr-low-1/2kd9vgx9",
}

process_runs(runs_to_process)
# Out:
# Processing run ol-state-dr-1/e3d4a367 to output folder /data/scratch/ankile/rr-best-checkpoints/bc/one_leg/low
# Modified weights for run ol-state-dr-1/e3d4a367 saved to /data/scratch/ankile/rr-best-checkpoints/bc/one_leg/low/actor_chkpt.pt
# Processing run ol-state-dr-med-1/9zjnzg4r to output folder /data/scratch/ankile/rr-best-checkpoints/bc/one_leg/med
# Modified weights for run ol-state-dr-med-1/9zjnzg4r saved to /data/scratch/ankile/rr-best-checkpoints/bc/one_leg/med/actor_chkpt.pt
# Processing run rt-state-dr-low-1/z3efusm6 to output folder /data/scratch/ankile/rr-best-checkpoints/bc/round_table/low
# Modified weights for run rt-state-dr-low-1/z3efusm6 saved to /data/scratch/ankile/rr-best-checkpoints/bc/round_table/low/actor_chkpt.pt
# Processing run rt-state-dr-med-1/n5g6x9jg to output folder /data/scratch/ankile/rr-best-checkpoints/bc/round_table/med
# Modified weights for run rt-state-dr-med-1/n5g6x9jg saved to /data/scratch/ankile/rr-best-checkpoints/bc/round_table/med/actor_chkpt.pt
# Processing run lp-state-dr-low-1/b5dcl1tt to output folder /data/scratch/ankile/rr-best-checkpoints/bc/lamp/low
# Modified weights for run lp-state-dr-low-1/b5dcl1tt saved to /data/scratch/ankile/rr-best-checkpoints/bc/lamp/low/actor_chkpt.pt
# Processing run lp-state-dr-med-1/fziwvs8k to output folder /data/scratch/ankile/rr-best-checkpoints/bc/lamp/med
# Modified weights for run lp-state-dr-med-1/fziwvs8k saved to /data/scratch/ankile/rr-best-checkpoints/bc/lamp/med/actor_chkpt.pt
# Processing run mr-state-dr-low-1/uet1h1ex to output folder /data/scratch/ankile/rr-best-checkpoints/bc/mug_rack/low
# Modified weights for run mr-state-dr-low-1/uet1h1ex saved to /data/scratch/ankile/rr-best-checkpoints/bc/mug_rack/low/actor_chkpt.pt
# Processing run fph-state-dr-low-1/4vwizwue to output folder /data/scratch/ankile/rr-best-checkpoints/bc/factory_peg_hole/low
# Modified weights for run fph-state-dr-low-1/4vwizwue saved to /data/scratch/ankile/rr-best-checkpoints/bc/factory_peg_hole/low/actor_chkpt.pt
# Processing run ol-rppo-dr-low-1/jamz5ley to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/one_leg/low
# Modified weights for run ol-rppo-dr-low-1/jamz5ley saved to /data/scratch/ankile/rr-best-checkpoints/rppo/one_leg/low/actor_chkpt.pt
# Processing run ol-rppo-dr-med-1/oipdyimz to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/one_leg/med
# Modified weights for run ol-rppo-dr-med-1/oipdyimz saved to /data/scratch/ankile/rr-best-checkpoints/rppo/one_leg/med/actor_chkpt.pt
# Processing run rt-rppo-dr-low-1/np48i8wp to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/round_table/low
# Modified weights for run rt-rppo-dr-low-1/np48i8wp saved to /data/scratch/ankile/rr-best-checkpoints/rppo/round_table/low/actor_chkpt.pt
# Processing run rt-rppo-dr-med-1/k737s8lj to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/round_table/med
# Modified weights for run rt-rppo-dr-med-1/k737s8lj saved to /data/scratch/ankile/rr-best-checkpoints/rppo/round_table/med/actor_chkpt.pt
# Processing run lp-rppo-dr-low-1/hd2i5gje to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/lamp/low
# Modified weights for run lp-rppo-dr-low-1/hd2i5gje saved to /data/scratch/ankile/rr-best-checkpoints/rppo/lamp/low/actor_chkpt.pt
# Processing run lp-rppo-dr-med-1/ev23t35c to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/lamp/med
# Modified weights for run lp-rppo-dr-med-1/ev23t35c saved to /data/scratch/ankile/rr-best-checkpoints/rppo/lamp/med/actor_chkpt.pt
# Processing run mr-rppo-dr-low-1/dvw6zk8e to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/mug_rack/low
# Modified weights for run mr-rppo-dr-low-1/dvw6zk8e saved to /data/scratch/ankile/rr-best-checkpoints/rppo/mug_rack/low/actor_chkpt.pt
# Processing run fph-rppo-dr-low-1/2kd9vgx9 to output folder /data/scratch/ankile/rr-best-checkpoints/rppo/factory_peg_hole/low
# Modified weights for run fph-rppo-dr-low-1/2kd9vgx9 saved to /data/scratch/ankile/rr-best-checkpoints/rppo/factory_peg_hole/low/actor_chkpt.pt
