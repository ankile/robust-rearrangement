# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
segments = [
    (142, 179),
    (-179, -1),
    (1, 108),
]

# %%
a = 142
x = -1

x - a + 360 * (abs(x) - x) / (2 * abs(x)) - 360 * (abs(a) - a) / (2 * abs(a))
# Out:
# 217.0

# %%
def phase_unwrap(x, a):
    return x - a + 360 * (abs(x) - x) / (2 * abs(x)) - 360 * (abs(a) - a) / (2 * abs(a))

# %%
def clamp_z_rotation(iz):
    # Phase unwrap the intrinsic rotation

    if iz > 130:
        iz = max(iz, 140)

    if iz < 120:
        iz = min(iz, 110)

    return iz

# %%
clamp_z_rotation(145), clamp_z_rotation(-1)
# Out:
# (145, -1)
