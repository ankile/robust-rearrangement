# %%
import os
from pathlib import Path
import numpy as np
import torch
import pickle
import matplotlib.pyplot as plt

from src.common.files import get_raw_paths
from src.visualization.render_mp4 import pickle_data, unpickle_data

# %%
# base_path = Path("/data/scratch-oc40/pulkitag/ankile/furniture-data/raw/diffik/real/one_leg_simple/teleop/low/success")
# pkl_paths = os.listdir(base_path)
# pkl_path = base_path / pkl_paths[0]

paths = get_raw_paths(
    controller="diffik",
    domain="real",
    task="one_leg_simple",
    demo_source="teleop",
    randomness="low",
    demo_outcome="success",
)

len(paths)
# Out:
# Found the following paths:
#     /data/scratch-oc40/pulkitag/ankile/furniture-data/raw/diffik/real/one_leg_simple/teleop/low/**/success/*.pkl*
# 50

# %%
data = unpickle_data(paths[0])

# %%
print(f'Data keys', data.keys())
observations = data['observations']
print(f'Obs length {len(observations)}, Obs keys', observations[0].keys())
# Out:
# Data keys dict_keys(['observations', 'actions', 'furniture', 'success', 'args', 'metadata'])
# Obs length 271, Obs keys dict_keys(['color_image1', 'color_image2', 'robot_state'])

# %%
obs = observations[100]

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 7)
ax[0].imshow(obs['color_image1'])
ax[1].imshow(obs['color_image2'])

# Turn off axis and remove white space
for a in ax:
    a.axis('off')
    a.margins(0, 0)

plt.subplots_adjust(wspace=0)

    
# plt.subplots_adjust(left=0, right=1, top=1, bottom=0)

plt.show()

# %%
obs = observations[100]
plt.imshow(obs['color_image1'])

# Turn off axis and remove white space
plt.axis('off')
plt.margins(0, 0)

plt.show()

plt.imshow(obs['color_image2'])

# Turn off axis and remove white space
plt.axis('off')
plt.margins(0, 0) 

plt.show()

# %%
import imageio
img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 17.56.18.png')
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 7)
ax[0].imshow(obs['color_image1'])
ax[1].imshow(img)
# plt.imshow(img)
ax[0].grid()
ax[1].grid()
plt.show()
# Out:
# /tmp/ipykernel_3314644/2213815589.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 17.56.18.png')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 import imageio
# ----> 2 img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 17.56.18.png')
#       3 fig, ax = plt.subplots(1, 2)
#       4 fig.set_size_inches(10, 7)
#
# File /data/scratch/ankile/miniconda3/envs/rr/lib/python3.8/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File /data/scratch/ankile/miniconda3/envs/rr/lib/python3.8/site-packages/imageio/v2.py:359, in imread(uri, format, **kwargs)
#     356 imopen_args = decypher_format_arg(format)
#     357 imopen_args["legacy_mode"] = True
# --> 359 with imopen(uri, "ri", **imopen_args) as file:
#     360     result = file.read(index=0, **kwargs)
#     362 return result
#
# File /data/scratch/ankile/miniconda3/envs/rr/lib/python3.8/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File /data/scratch/ankile/miniconda3/envs/rr/lib/python3.8/site-packages/imageio/core/request.py:247, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     244     raise ValueError(f"Invalid Request.Mode: {mode}")
#     246 # Parse what was given
# --> 247 self._parse_uri(uri)
#     249 # Set extension
#     250 if extension is not None:
#
# File /data/scratch/ankile/miniconda3/envs/rr/lib/python3.8/site-packages/imageio/core/request.py:407, in Request._parse_uri(self, uri)
#     404 if is_read_request:
#     405     # Reading: check that the file exists (but is allowed a dir)
#     406     if not os.path.exists(fn):
# --> 407         raise FileNotFoundError("No such file: '%s'" % fn)
#     408 else:
#     409     # Writing: check that the directory to write to does exist
#     410     dn = os.path.dirname(fn)
#
# FileNotFoundError: No such file: '/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 17.56.18.png'

# %%
import imageio
img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 15.43.20.png')
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 7)
ax[0].imshow(obs['color_image2'])
ax[1].imshow(img)
# plt.imshow(img)
ax[0].grid()
ax[1].grid()
plt.show()
# Out:
# /tmp/ipykernel_130671/2033636335.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-21 15.43.20.png')

# %%
import imageio
img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-22 15.03.51.png')
# img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-22 14.52.58.png')
fig, ax = plt.subplots(1, 2)
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10, 7)
ax[0].imshow(obs['color_image2'])
ax[1].imshow(img)
plt.show()
# Out:
# /tmp/ipykernel_223002/2316883528.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('/home/anthony/Documents/Kit/shared/screenshots/capture.2024-05-22 15.03.51.png')
