# %%
import pytorch3d.transforms as pt
import zarr
import numpy as np
import torch

# %%
def numpy_quaternion_to_6d(quaternions_np):
    # Convert the numpy array of quaternions to a PyTorch tensor
    quaternions = torch.from_numpy(quaternions_np).float()

    # Move the real part from the back to the front
    quaternions = torch.cat([quaternions[:, -1:], quaternions[:, :-1]], dim=1)

    # Convert each quaternion to a rotation matrix
    rot_mats = pt.quaternion_to_matrix(quaternions)

    # Extract the first two columns of each rotation matrix
    six_d_representations = pt.matrix_to_rotation_6d(rot_mats)

    # Convert the results back to a numpy array
    return six_d_representations.numpy()

# %%
dataset = zarr.open(
    "/data/scratch/ankile/furniture-data/processed/sim/feature/vip/combined.zarr",
    mode="a",
)

# %%
rot_quat = dataset["action"][:, 3:7]

rot_quat.shape
# Out:
# (1128470, 4)

# %%
rot_6d = numpy_quaternion_to_6d(rot_quat)

rot_6d.shape
# Out:
# (1128470, 6)

# %%
action_6d = np.concatenate(
    [dataset["action"][:, :3], rot_6d, dataset["action"][:, 7:]], axis=1
)

action_6d.shape
# Out:
# (1128470, 10)

# %%
dataset["action_6d"] = action_6d

# %%
# Get the stats and store them
from src.dataset.normalizer import get_data_stats

# %%
stats = get_data_stats(action_6d)

stats
# Out:
# {'min': array([-0.11999829, -0.11999908, -0.08132574, -0.35798502, -0.99999934,
#         -0.70630395, -0.99999964, -0.28959465, -0.89785737, -1.        ],
#        dtype=float32),
#  'max': array([0.11999787, 0.11999953, 0.07999872, 1.        , 0.9999992 ,
#         0.9999981 , 0.9999772 , 1.        , 0.49280044, 1.        ],
#        dtype=float32)}

# %%
stats = get_data_stats(action_6d)

stats
# Out:
# {'min': array([-0.11999926, -0.1199997 , -0.08132574, -0.99995553, -0.9999999 ,
#         -0.9951642 , -0.99999964, -0.99929166, -0.89785737, -1.        ],
#        dtype=float32),
#  'max': array([0.11999996, 0.11999957, 0.09052899, 1.        , 0.9999998 ,
#         0.9999981 , 0.99999875, 1.        , 0.59187496, 1.        ],
#        dtype=float32)}

# %%
dataset = zarr.open(
    "test.zarr",
    mode="w",
)

# %%
# Add nested groups to the root group
dataset.create_group("action")
dataset.create_group("action/6d")
dataset.create_group("action/quat")
# Out:
# <zarr.hierarchy.Group '/action/quat'>

# %%
# Add data to the nested groups
dataset["action/6d"] = np.random.rand(100, 6)
dataset["action/quat"] = np.random.rand(100, 4)

# %%
# Read the data in the 6D group
dataset["action"]["6d"][:]
# Out:
# array([[4.84917336e-01, 8.50956869e-01, 6.51772583e-01, 3.67672811e-02,
#         6.48657343e-01, 2.48006422e-01],
#        [4.68869580e-01, 5.87572016e-01, 9.15825188e-01, 8.92789343e-01,
#         1.68138574e-01, 1.96886635e-01],
#        [6.16899284e-01, 7.67222054e-01, 3.52560971e-01, 1.82418605e-02,
#         7.23581650e-01, 6.93448497e-01],
#        [6.34723881e-01, 5.25868809e-01, 2.89767354e-01, 3.77854309e-01,
#         4.78354634e-01, 8.50765909e-01],
#        [3.96843786e-01, 1.35549528e-02, 6.95884271e-01, 5.16376423e-01,
#         2.99139903e-01, 1.60586352e-01],
#        [4.34144796e-01, 2.33181798e-01, 5.46062537e-01, 1.90481390e-01,
#         8.56172761e-01, 9.74144590e-01],
#        [9.47299057e-02, 2.90233478e-01, 6.00643081e-01, 8.10123522e-01,
#         7.90540294e-01, 3.59834045e-01],
#        [5.09921135e-01, 2.89706290e-01, 5.72463171e-02, 3.43007171e-01,
#         6.56968534e-01, 8.25113748e-01],
#        [6.09609445e-03, 1.78463010e-01, 9.71690445e-01, 7.45251627e-01,
#         9.01785251e-01, 5.35385806e-01],
#        [6.05654209e-01, 3.86950706e-01, 1.50242573e-01, 7.83520539e-01,
#         2.65401311e-01, 3.07994529e-01],
#        [6.58167014e-01, 2.20917134e-01, 4.42248466e-01, 1.70235273e-01,
#         4.73216695e-01, 1.96385427e-01],
#        [4.06017357e-03, 9.36080510e-01, 3.68649478e-01, 5.84002047e-01,
#         2.45649791e-01, 7.41327369e-01],
#        [8.84129161e-01, 1.75398215e-01, 8.00564880e-01, 5.11292671e-01,
#         2.63635306e-01, 5.30863261e-01],
#        [4.09841991e-01, 1.13686973e-03, 6.54427125e-02, 3.30127969e-01,
#         8.95532946e-01, 4.03931317e-01],
#        [3.97301364e-01, 8.16644077e-01, 6.69658919e-01, 4.72601208e-01,
#         2.17558494e-01, 6.40044954e-01],
#        [7.40604470e-01, 7.11283769e-01, 4.46215690e-01, 2.17684842e-02,
#         5.75132498e-01, 3.59180689e-01],
#        [1.36641388e-01, 4.53287851e-01, 3.96879528e-01, 7.10818576e-01,
#         5.44412762e-01, 4.11649699e-02],
#        [4.63879655e-01, 3.71051759e-01, 9.72124979e-01, 4.26232994e-01,
#         2.87856117e-01, 8.64806560e-01],
#        [5.40748524e-01, 6.83740492e-01, 9.90432925e-01, 2.93904128e-01,
#         9.23413291e-02, 4.10662495e-01],
#        [2.91967477e-01, 3.82619174e-02, 9.29916291e-01, 6.53320955e-01,
#         9.20060107e-01, 8.53139388e-01],
#        [4.98959798e-02, 4.41311116e-02, 7.22799956e-01, 1.44685132e-01,
#         5.88500148e-01, 7.27368797e-01],
#        [2.06055103e-01, 6.20601956e-01, 3.57542934e-01, 7.03321079e-02,
#         1.60684178e-01, 9.04781179e-01],
#        [8.55293503e-01, 7.83869138e-02, 4.94560587e-01, 7.86056414e-01,
#         9.89612268e-01, 2.36507093e-02],
#        [7.26983493e-01, 6.94030334e-01, 7.16235574e-01, 8.14858625e-01,
#         2.79404410e-01, 5.67513787e-01],
#        [5.87516172e-01, 5.76309050e-01, 8.53186085e-01, 6.63942339e-02,
#         1.01253727e-01, 2.64066079e-01],
#        [9.87103329e-01, 6.06608778e-01, 8.92340218e-01, 3.34916322e-01,
#         1.61643520e-01, 9.78830373e-01],
#        [4.75721428e-01, 4.32099915e-01, 8.31915683e-01, 7.66827918e-01,
#         8.59336224e-01, 6.88235541e-01],
#        [8.14566009e-01, 2.36454143e-01, 6.12696548e-02, 2.54493798e-01,
#         7.59240049e-01, 8.38023757e-01],
#        [9.42270021e-01, 4.59482063e-02, 6.33670761e-02, 6.66021776e-01,
#         3.50005392e-01, 8.89794920e-01],
#        [4.70090891e-01, 3.73137038e-01, 8.10912607e-01, 1.16832005e-01,
#         4.52909720e-01, 1.31264866e-01],
#        [2.84731873e-02, 3.62052571e-01, 3.61346422e-01, 5.76715818e-01,
#         1.51539831e-01, 9.14557540e-01],
#        [6.56424552e-01, 1.05210655e-01, 1.99664357e-01, 6.70508377e-01,
#         3.96149935e-01, 4.91280082e-01],
#        [1.74187103e-01, 6.76926334e-01, 5.73290560e-01, 5.21695810e-01,
#         9.07599428e-01, 8.08234704e-01],
#        [7.41151858e-01, 2.96244252e-01, 6.67735352e-01, 5.63910623e-01,
#         2.82959325e-01, 6.90414481e-01],
#        [8.50959144e-01, 3.19509178e-01, 7.10013838e-01, 6.23442916e-01,
#         3.81005943e-01, 6.03810786e-01],
#        [2.40744138e-01, 4.81257611e-01, 9.44067854e-01, 3.33770880e-01,
#         9.15199079e-01, 6.70691771e-01],
#        [9.89379654e-02, 1.14309759e-01, 5.84439994e-04, 4.17256089e-01,
#         2.09773770e-01, 5.43941026e-01],
#        [2.20368588e-01, 7.75107925e-01, 7.69528745e-01, 7.89571101e-01,
#         4.78295983e-01, 2.37747996e-02],
#        [6.75002158e-01, 7.00137651e-02, 4.36886405e-02, 8.32478195e-02,
#         2.37030727e-01, 8.41503955e-01],
#        [1.26665734e-01, 1.14577787e-01, 8.45944570e-01, 7.35080739e-01,
#         6.73646228e-01, 6.14146515e-01],
#        [9.17049369e-01, 4.78048584e-01, 8.61997924e-01, 5.70120152e-01,
#         9.06054868e-01, 4.48808647e-01],
#        [5.37121690e-01, 5.59787825e-01, 6.08806829e-01, 2.82403938e-01,
#         8.87488253e-01, 6.42720285e-01],
#        [1.74876575e-01, 9.99443269e-01, 2.23160675e-01, 6.10603106e-01,
#         9.56185447e-01, 7.93895575e-01],
#        [7.15327436e-01, 3.74273046e-01, 9.69782305e-03, 1.09591424e-01,
#         4.85709371e-01, 8.60452268e-02],
#        [2.77659987e-03, 3.98576347e-01, 3.63809260e-01, 7.21549575e-01,
#         6.02025417e-01, 4.45445375e-01],
#        [9.44528719e-01, 1.43117870e-01, 7.05988687e-01, 4.78330970e-01,
#         3.16217193e-01, 9.92657430e-01],
#        [4.58735451e-01, 7.03517120e-02, 8.16734501e-01, 9.23089739e-01,
#         9.33556355e-01, 7.68437797e-01],
#        [6.06300170e-01, 7.43616601e-01, 2.38321052e-01, 3.93660447e-01,
#         3.22601343e-01, 1.89466787e-01],
#        [4.50245934e-01, 1.37665426e-01, 6.87869232e-01, 7.62207719e-01,
#         6.39636634e-01, 8.86555264e-01],
#        [1.86228212e-02, 7.26439611e-01, 1.68963926e-01, 9.18229022e-01,
#         8.87187004e-01, 7.30560585e-01],
#        [7.44102523e-01, 3.28043121e-01, 8.07971814e-02, 4.05663549e-03,
#         5.19675279e-01, 4.33135067e-01],
#        [9.94763364e-01, 5.27386333e-01, 3.60718436e-02, 9.65068464e-01,
#         4.08018838e-01, 4.80776107e-01],
#        [1.82511393e-01, 3.47658437e-01, 4.37821246e-01, 9.89636182e-01,
#         1.05189288e-01, 7.86579927e-01],
#        [3.37147570e-01, 1.27982284e-01, 7.76588175e-01, 6.97321629e-01,
#         9.71722936e-02, 8.97126113e-01],
#        [4.68854831e-01, 6.92831510e-01, 9.30410079e-01, 4.58596653e-01,
#         1.83621014e-01, 1.07172354e-01],
#        [5.63603149e-01, 2.24004050e-01, 2.24467519e-01, 3.71307315e-01,
#         8.65499907e-01, 4.68590577e-01],
#        [1.84981695e-01, 3.14479482e-01, 4.25262550e-01, 8.49888578e-01,
#         5.61418301e-01, 5.52225197e-01],
#        [8.41780921e-01, 8.22334943e-01, 7.31667820e-01, 3.43066356e-01,
#         5.40151659e-01, 3.88566804e-01],
#        [7.78640928e-01, 9.14720713e-01, 7.46257774e-01, 6.77153749e-02,
#         1.59648032e-01, 3.34695001e-01],
#        [7.33761505e-01, 2.19472208e-01, 8.25040257e-01, 7.39624814e-01,
#         9.50356075e-01, 7.54700941e-01],
#        [1.54385796e-02, 5.17687529e-01, 1.42645848e-01, 1.61527227e-01,
#         3.41764114e-02, 6.40992356e-01],
#        [6.91597148e-01, 3.48171658e-01, 8.93042925e-01, 7.73735800e-01,
#         5.49372469e-01, 9.81870376e-01],
#        [5.12657533e-01, 5.46033855e-01, 8.38051579e-01, 1.39017108e-01,
#         4.81207368e-02, 1.40591463e-01],
#        [2.88142924e-01, 2.75477284e-02, 5.24296715e-01, 6.21019078e-02,
#         4.77257291e-01, 5.29399483e-01],
#        [7.47972020e-01, 7.32293062e-01, 7.43976334e-01, 4.53790169e-01,
#         7.13690725e-01, 8.77335729e-01],
#        [4.93974482e-01, 8.11557913e-01, 7.30223915e-01, 6.07271458e-01,
#         2.59374145e-01, 3.69445735e-01],
#        [5.68205448e-01, 5.92538913e-01, 4.02803356e-01, 7.83597169e-01,
#         2.12766917e-01, 9.08457807e-01],
#        [6.51332888e-01, 5.77842366e-01, 3.76237165e-02, 2.08874866e-03,
#         2.30304792e-01, 7.82469565e-01],
#        [5.71016505e-01, 2.10747075e-01, 7.87426185e-01, 8.49731784e-01,
#         8.86646731e-01, 3.25305485e-01],
#        [3.53417552e-01, 3.67665029e-01, 9.88418285e-01, 7.72568716e-01,
#         9.62503831e-01, 6.89864054e-01],
#        [7.37997136e-01, 6.96461521e-01, 2.02721383e-01, 9.90107101e-01,
#         9.70641560e-01, 1.45081604e-02],
#        [4.96865224e-01, 1.33627004e-01, 1.59060799e-01, 3.19061103e-01,
#         7.31010448e-01, 8.47608965e-01],
#        [1.53355615e-01, 6.01561099e-03, 8.15851850e-01, 8.88094874e-01,
#         1.50356994e-01, 7.56989605e-01],
#        [7.48384761e-01, 1.07004489e-01, 7.83834183e-01, 3.46124555e-01,
#         8.10741275e-01, 6.09164583e-01],
#        [6.26407306e-01, 2.60157464e-01, 2.98899784e-01, 3.92286210e-01,
#         1.90892692e-01, 5.02752297e-01],
#        [1.92282388e-03, 2.23575156e-01, 5.42386777e-01, 8.78541332e-01,
#         2.58720757e-01, 5.85947904e-01],
#        [7.97157642e-02, 6.07333933e-01, 9.46186930e-01, 2.73207743e-02,
#         3.06364113e-01, 9.79082143e-01],
#        [9.81138806e-01, 7.18933540e-01, 4.82086884e-01, 2.85664972e-01,
#         7.93551267e-01, 2.82587947e-01],
#        [6.04187327e-01, 9.59553055e-01, 3.40417061e-01, 7.77429930e-01,
#         6.57933334e-01, 4.35347900e-01],
#        [8.79893587e-01, 4.84948915e-01, 5.24237925e-01, 3.65959585e-01,
#         9.64211864e-01, 1.94799349e-01],
#        [9.80914392e-01, 4.24187574e-01, 9.31974362e-01, 5.27869017e-01,
#         4.54507222e-01, 5.93566144e-01],
#        [7.37461258e-01, 3.61555071e-01, 6.80036099e-01, 9.36978922e-01,
#         4.84978876e-01, 6.80208307e-01],
#        [1.05871041e-01, 6.04493205e-01, 8.64432610e-01, 4.97987836e-01,
#         9.88904900e-01, 3.07693577e-01],
#        [5.50548344e-02, 5.64463132e-01, 2.06245832e-01, 1.70637443e-01,
#         3.41827177e-01, 5.75890916e-01],
#        [3.09395877e-01, 1.33851776e-01, 5.74066696e-02, 1.75482247e-01,
#         5.96252092e-01, 2.00761907e-01],
#        [2.20869908e-01, 2.17047492e-03, 3.85597844e-01, 3.18546262e-01,
#         7.71406150e-01, 8.96721292e-01],
#        [3.11351107e-01, 7.18596033e-02, 6.20272527e-02, 9.42031181e-01,
#         2.53844327e-01, 9.86191729e-01],
#        [4.00620997e-02, 8.00175336e-01, 2.14699379e-01, 1.95814506e-01,
#         8.50306473e-01, 3.23238660e-01],
#        [4.44499346e-01, 4.95512021e-02, 3.10117985e-01, 7.05105181e-01,
#         6.26538635e-01, 8.84293352e-01],
#        [4.58907522e-03, 1.63988242e-01, 2.78791699e-01, 5.18012224e-02,
#         2.06228162e-01, 2.67810828e-01],
#        [8.46872396e-01, 9.25123586e-01, 7.76306914e-01, 8.03631619e-01,
#         3.87634080e-01, 6.06012148e-01],
#        [9.49661855e-01, 2.23600363e-01, 7.75113721e-01, 6.40878455e-02,
#         7.20484691e-01, 8.36651481e-01],
#        [9.39599184e-01, 3.80973244e-01, 4.45028460e-01, 7.24559925e-01,
#         8.55053871e-01, 6.11185069e-01],
#        [3.73752170e-01, 5.57686253e-01, 6.51993363e-03, 7.42031250e-01,
#         2.22299312e-01, 8.06761722e-01],
#        [7.05872703e-01, 4.71314642e-01, 5.17881620e-01, 9.29282147e-01,
#         6.62154769e-01, 8.05754918e-01],
#        [1.83882361e-01, 9.82652026e-02, 5.01115007e-01, 2.79625032e-01,
#         3.09983742e-01, 3.07128803e-01],
#        [9.43304813e-01, 1.00244540e-01, 1.55280783e-01, 7.11916573e-01,
#         5.08394368e-01, 3.57340740e-01],
#        [7.89833510e-01, 5.48634859e-01, 3.98250145e-01, 6.25105549e-01,
#         2.09860228e-01, 9.43473903e-01],
#        [1.48620765e-01, 1.00915060e-01, 3.58446252e-01, 2.05576895e-01,
#         2.89728567e-01, 8.71684800e-01],
#        [7.17786706e-01, 1.51391461e-01, 7.95407203e-01, 3.88099866e-01,
#         5.33530751e-01, 3.73828890e-01]])

# %%
from glob import glob
from pathlib import Path
from src.visualization.render_mp4 import unpickle_data

# %%
paths = [
    Path(p)
    for p in glob(
        "/data/scratch-oc40/pulkitag/ankile/furniture-data/raw/sim/one_leg/scripted/**/success/*.pkl*",
        recursive=True,
    )
]

# %%
data = unpickle_data(paths[0])

# %%
len(data["observations"]), len(data["actions"]), len(data["rewards"])
# Out:
# (576, 575, 575)
